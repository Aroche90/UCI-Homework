# %%
import pandas as pd
from sqlalchemy import create_engine
from config import user, password
import datetime as dt

# %%
user
# Out:
# 'postgres'

# %%
password
# Out:
# 'postgres'

# %%
flight_data = "Resources/flights.csv"
flight_df = pd.read_csv(flight_data, dtype={'SCHEDULED_DEPARTURE': str, 'DEPARTURE_TIME': str})
flight_df.head()
# Out:
# /Users/andrewroche/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE  ... ARRIVAL_TIME  \
# 0            ANC                 SEA                0005  ...        408.0
# 1            LAX                 PBI                0010  ...        741.0
# ...

# %%
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE                object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    object
# DEPARTURE_TIME         object
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# ...

# %%
weather_data = "Resources/weather_description.csv"
weather_df = pd.read_csv(weather_data)
weather_df.head()
# Out:
#               datetime      Vancouver          Portland San Francisco  \
# 0  2012-10-01 12:00:00            NaN               NaN           NaN
# 1  2012-10-01 13:00:00           mist  scattered clouds    light rain
# 2  2012-10-01 14:00:00  broken clouds  scattered clouds  sky is clear
# 3  2012-10-01 15:00:00  broken clouds  scattered clouds  sky is clear
# 4  2012-10-01 16:00:00  broken clouds  scattered clouds  sky is clear
#
#         Seattle   Los Angeles     San Diego     Las Vegas       Phoenix  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  sky is clear          mist  sky is clear  sky is clear  sky is clear
# 2  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 3  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 4  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
#
#     Albuquerque  ...   Philadelphia    New York         Montreal  \
# ...

# %%
airport_data = "Resources/airports.csv"
airport_df = pd.read_csv(airport_data)
airport_df.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
airport_df[airport_df["CITY"] == "Chicago"]
# Out:
#     IATA_CODE                               AIRPORT     CITY STATE COUNTRY  \
# 195       MDW  Chicago Midway International Airport  Chicago    IL     USA
# 228       ORD  Chicago O'Hare International Airport  Chicago    IL     USA
#
#      LATITUDE  LONGITUDE
# 195  41.78598  -87.75242
# 228  41.97960  -87.90446

# %%
airport_df[airport_df["CITY"] == "San Francisco"]
# Out:
#     IATA_CODE                              AIRPORT           CITY STATE  \
# 278       SFO  San Francisco International Airport  San Francisco    CA
#
#     COUNTRY  LATITUDE  LONGITUDE
# 278     USA    37.619 -122.37484

# %%
airport_df[airport_df["CITY"] == "New York"]
# Out:
#     IATA_CODE                                            AIRPORT      CITY  \
# 166       JFK  John F. Kennedy International Airport (New Yor...  New York
# 182       LGA            LaGuardia Airport (Marine Air Terminal)  New York
#
#     STATE COUNTRY  LATITUDE  LONGITUDE
# 166    NY     USA  40.63975  -73.77893
# 182    NY     USA  40.77724  -73.87261

# %%
airport_df[airport_df["CITY"] == "Atlanta"]
# Out:
#    IATA_CODE                                           AIRPORT     CITY STATE  \
# 20       ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta    GA
#
#    COUNTRY  LATITUDE  LONGITUDE
# 20     USA  33.64044  -84.42694

# %%
airport_df[airport_df["CITY"] == "Kansas City"]
# Out:
#     IATA_CODE                            AIRPORT         CITY STATE COUNTRY  \
# 192       MCI  Kansas City International Airport  Kansas City    MO     USA
#
#      LATITUDE  LONGITUDE
# 192  39.29761  -94.71391

# %%
list(flight_df)
# Out:
# ['YEAR',
#  'MONTH',
#  'DAY',
#  'DAY_OF_WEEK',
#  'AIRLINE',
#  'FLIGHT_NUMBER',
#  'TAIL_NUMBER',
#  'ORIGIN_AIRPORT',
#  'DESTINATION_AIRPORT',
#  'SCHEDULED_DEPARTURE',
#  'DEPARTURE_TIME',
#  'DEPARTURE_DELAY',
#  'TAXI_OUT',
#  'WHEELS_OFF',
#  'SCHEDULED_TIME',
#  'ELAPSED_TIME',
#  'AIR_TIME',
#  'DISTANCE',
#  'WHEELS_ON',
#  'TAXI_IN',
#  'SCHEDULED_ARRIVAL',
#  'ARRIVAL_TIME',
#  'ARRIVAL_DELAY',
#  'DIVERTED',
#  'CANCELLED',
#  'CANCELLATION_REASON',
#  'AIR_SYSTEM_DELAY',
#  'SECURITY_DELAY',
#  'AIRLINE_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'WEATHER_DELAY']

# %%
list(weather_df)
# Out:
# ['datetime',
#  'Vancouver',
#  'Portland',
#  'San Francisco',
#  'Seattle',
#  'Los Angeles',
#  'San Diego',
#  'Las Vegas',
#  'Phoenix',
#  'Albuquerque',
#  'Denver',
#  'San Antonio',
#  'Dallas',
#  'Houston',
#  'Kansas City',
#  'Minneapolis',
#  'Saint Louis',
#  'Chicago',
#  'Nashville',
#  'Indianapolis',
#  'Atlanta',
#  'Detroit',
#  'Jacksonville',
#  'Charlotte',
#  'Miami',
#  'Pittsburgh',
#  'Toronto',
#  'Philadelphia',
#  'New York',
#  'Montreal',
#  'Boston',
#  'Beersheba',
#  'Tel Aviv District',
#  'Eilat',
#  'Haifa',
#  'Nahariyya',
#  'Jerusalem']

# %%
flights_df = flight_df.loc[:,['YEAR', 'MONTH', 'DAY', 'FLIGHT_NUMBER', 'ORIGIN_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'CANCELLED', 'CANCELLATION_REASON']]
flights_df.head()
# Out:
#    YEAR  MONTH  DAY  FLIGHT_NUMBER ORIGIN_AIRPORT SCHEDULED_DEPARTURE  \
# 0  2015      1    1             98            ANC                0005
# 1  2015      1    1           2336            LAX                0010
# 2  2015      1    1            840            SFO                0020
# 3  2015      1    1            258            LAX                0020
# 4  2015      1    1            135            SEA                0025
#
#   DEPARTURE_TIME  DEPARTURE_DELAY  CANCELLED CANCELLATION_REASON
# 0           2354            -11.0          0                 NaN
# 1           0002             -8.0          0                 NaN
# 2           0018             -2.0          0                 NaN
# 3           0015             -5.0          0                 NaN
# 4           0024             -1.0          0                 NaN

# %%
airports_df = airport_df.loc[:,['IATA_CODE', 'AIRPORT', 'CITY', 'STATE']]
airports_df.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE
# 0       ABE  Lehigh Valley International Airport    Allentown    PA
# 1       ABI             Abilene Regional Airport      Abilene    TX
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA

# %%
weather_df2 = weather_df.loc[:,['datetime', 'Atlanta', 'Chicago', 'Kansas City', 'New York', 'San Francisco']]
weather_df2.head()
# Out:
#               datetime          Atlanta          Chicago   Kansas City  \
# 0  2012-10-01 12:00:00              NaN              NaN           NaN
# 1  2012-10-01 13:00:00       light rain  overcast clouds  sky is clear
# 2  2012-10-01 14:00:00  overcast clouds  overcast clouds  sky is clear
# 3  2012-10-01 15:00:00  overcast clouds  overcast clouds  sky is clear
# 4  2012-10-01 16:00:00  overcast clouds  overcast clouds  sky is clear
#
#      New York San Francisco
# 0         NaN           NaN
# 1  few clouds    light rain
# 2  few clouds  sky is clear
# 3  few clouds  sky is clear
# 4  few clouds  sky is clear

# %%
weather_df2 = weather_df2.rename(columns={"Atlanta": "atlanta", "Chicago": "chicago", "Kansas City": "kansas_city", "New York": "new_york", "San Francisco": "san_francisco"})
weather_df2.head()
# Out:
#               datetime          atlanta          chicago   kansas_city  \
# 0  2012-10-01 12:00:00              NaN              NaN           NaN
# 1  2012-10-01 13:00:00       light rain  overcast clouds  sky is clear
# 2  2012-10-01 14:00:00  overcast clouds  overcast clouds  sky is clear
# 3  2012-10-01 15:00:00  overcast clouds  overcast clouds  sky is clear
# 4  2012-10-01 16:00:00  overcast clouds  overcast clouds  sky is clear
#
#      new_york san_francisco
# 0         NaN           NaN
# 1  few clouds    light rain
# 2  few clouds  sky is clear
# 3  few clouds  sky is clear
# 4  few clouds  sky is clear

# %%
flights_df = flights_df.rename(columns={"ORIGIN_AIRPORT": "airport_code", "CANCELLED": "CANCELLATION"})
flights_df.head()
# Out:
#    YEAR  MONTH  DAY  FLIGHT_NUMBER airport_code SCHEDULED_DEPARTURE  \
# 0  2015      1    1             98          ANC                0005
# 1  2015      1    1           2336          LAX                0010
# 2  2015      1    1            840          SFO                0020
# 3  2015      1    1            258          LAX                0020
# 4  2015      1    1            135          SEA                0025
#
#   DEPARTURE_TIME  DEPARTURE_DELAY  CANCELLATION CANCELLATION_REASON
# 0           2354            -11.0             0                 NaN
# 1           0002             -8.0             0                 NaN
# 2           0018             -2.0             0                 NaN
# 3           0015             -5.0             0                 NaN
# 4           0024             -1.0             0                 NaN

# %%
airports_df = airports_df.rename(columns={'IATA_CODE': "airport_code"})
airports_df.head()
# Out:
#   airport_code                              AIRPORT         CITY STATE
# 0          ABE  Lehigh Valley International Airport    Allentown    PA
# 1          ABI             Abilene Regional Airport      Abilene    TX
# 2          ABQ    Albuquerque International Sunport  Albuquerque    NM
# 3          ABR            Aberdeen Regional Airport     Aberdeen    SD
# 4          ABY   Southwest Georgia Regional Airport       Albany    GA

# %%
airports_df = airports_df[airports_df["airport_code"].isin(["ORD", "JFK", "SFO", "MCI", "ATL"])]
airports_df.head()
# Out:
#     airport_code                                            AIRPORT  \
# 20           ATL   Hartsfield-Jackson Atlanta International Airport
# 166          JFK  John F. Kennedy International Airport (New Yor...
# 192          MCI                  Kansas City International Airport
# 228          ORD               Chicago O'Hare International Airport
# 278          SFO                San Francisco International Airport
#
#               CITY STATE
# 20         Atlanta    GA
# 166       New York    NY
# 192    Kansas City    MO
# 228        Chicago    IL
# 278  San Francisco    CA

# %%
merge_table = pd.merge(airports_df, flights_df, on="airport_code")
merge_table.head()
# Out:
#   airport_code                                           AIRPORT     CITY  \
# 0          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 1          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 2          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 3          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 4          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
#
#   STATE  YEAR  MONTH  DAY  FLIGHT_NUMBER SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 0    GA  2015      1    1           3268                0540           0556
# 1    GA  2015      1    1            902                0600           0619
# 2    GA  2015      1    1           1635                0625            NaN
# 3    GA  2015      1    1            886                0645           0644
# 4    GA  2015      1    1           4974                0646           0642
#
#    DEPARTURE_DELAY  CANCELLATION CANCELLATION_REASON
# ...

# %%
merge_table[merge_table["airport_code"] == "ORD"]
# Out:
#        airport_code                               AIRPORT     CITY STATE  \
# 479312          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479313          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479314          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479315          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479316          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479317          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479318          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479319          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479320          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479321          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479322          ORD  Chicago O'Hare International Airport  Chicago    IL
# 479323          ORD  Chicago O'Hare International Airport  Chicago    IL
# ...

# %%
merge_table[merge_table["airport_code"] == "SFO"]
# Out:
#        airport_code                              AIRPORT           CITY STATE  \
# 765196          SFO  San Francisco International Airport  San Francisco    CA
# 765197          SFO  San Francisco International Airport  San Francisco    CA
# 765198          SFO  San Francisco International Airport  San Francisco    CA
# 765199          SFO  San Francisco International Airport  San Francisco    CA
# 765200          SFO  San Francisco International Airport  San Francisco    CA
# 765201          SFO  San Francisco International Airport  San Francisco    CA
# 765202          SFO  San Francisco International Airport  San Francisco    CA
# 765203          SFO  San Francisco International Airport  San Francisco    CA
# 765204          SFO  San Francisco International Airport  San Francisco    CA
# 765205          SFO  San Francisco International Airport  San Francisco    CA
# 765206          SFO  San Francisco International Airport  San Francisco    CA
# ...

# %%
merge_table[merge_table["airport_code"] == "JFK"]
# Out:
#        airport_code                                            AIRPORT  \
# 346836          JFK  John F. Kennedy International Airport (New Yor...
# 346837          JFK  John F. Kennedy International Airport (New Yor...
# 346838          JFK  John F. Kennedy International Airport (New Yor...
# 346839          JFK  John F. Kennedy International Airport (New Yor...
# 346840          JFK  John F. Kennedy International Airport (New Yor...
# 346841          JFK  John F. Kennedy International Airport (New Yor...
# 346842          JFK  John F. Kennedy International Airport (New Yor...
# 346843          JFK  John F. Kennedy International Airport (New Yor...
# 346844          JFK  John F. Kennedy International Airport (New Yor...
# 346845          JFK  John F. Kennedy International Airport (New Yor...
# 346846          JFK  John F. Kennedy International Airport (New Yor...
# 346847          JFK  John F. Kennedy International Airport (New Yor...
# ...

# %%
merge_table[merge_table["airport_code"] == "MCI"]
# Out:
#        airport_code                            AIRPORT         CITY STATE  \
# 440647          MCI  Kansas City International Airport  Kansas City    MO
# 440648          MCI  Kansas City International Airport  Kansas City    MO
# 440649          MCI  Kansas City International Airport  Kansas City    MO
# 440650          MCI  Kansas City International Airport  Kansas City    MO
# 440651          MCI  Kansas City International Airport  Kansas City    MO
# 440652          MCI  Kansas City International Airport  Kansas City    MO
# 440653          MCI  Kansas City International Airport  Kansas City    MO
# 440654          MCI  Kansas City International Airport  Kansas City    MO
# 440655          MCI  Kansas City International Airport  Kansas City    MO
# 440656          MCI  Kansas City International Airport  Kansas City    MO
# 440657          MCI  Kansas City International Airport  Kansas City    MO
# 440658          MCI  Kansas City International Airport  Kansas City    MO
# ...

# %%
merge_table[merge_table["airport_code"] == "ATL"]
# Out:
#        airport_code                                           AIRPORT  \
# 0               ATL  Hartsfield-Jackson Atlanta International Airport
# 1               ATL  Hartsfield-Jackson Atlanta International Airport
# 2               ATL  Hartsfield-Jackson Atlanta International Airport
# 3               ATL  Hartsfield-Jackson Atlanta International Airport
# 4               ATL  Hartsfield-Jackson Atlanta International Airport
# 5               ATL  Hartsfield-Jackson Atlanta International Airport
# 6               ATL  Hartsfield-Jackson Atlanta International Airport
# 7               ATL  Hartsfield-Jackson Atlanta International Airport
# 8               ATL  Hartsfield-Jackson Atlanta International Airport
# 9               ATL  Hartsfield-Jackson Atlanta International Airport
# 10              ATL  Hartsfield-Jackson Atlanta International Airport
# 11              ATL  Hartsfield-Jackson Atlanta International Airport
# ...

# %%
merge_table[merge_table["airport_code"].isin(["ORD", "JFK", "SFO", "MCI", "ATL"])]
# Out:
#        airport_code                                           AIRPORT  \
# 0               ATL  Hartsfield-Jackson Atlanta International Airport
# 1               ATL  Hartsfield-Jackson Atlanta International Airport
# 2               ATL  Hartsfield-Jackson Atlanta International Airport
# 3               ATL  Hartsfield-Jackson Atlanta International Airport
# 4               ATL  Hartsfield-Jackson Atlanta International Airport
# 5               ATL  Hartsfield-Jackson Atlanta International Airport
# 6               ATL  Hartsfield-Jackson Atlanta International Airport
# 7               ATL  Hartsfield-Jackson Atlanta International Airport
# 8               ATL  Hartsfield-Jackson Atlanta International Airport
# 9               ATL  Hartsfield-Jackson Atlanta International Airport
# 10              ATL  Hartsfield-Jackson Atlanta International Airport
# 11              ATL  Hartsfield-Jackson Atlanta International Airport
# ...

# %%
merged_table = merge_table[merge_table["airport_code"].isin(["ORD", "JFK", "SFO", "MCI", "ATL"])]
merged_table.head()
# Out:
#   airport_code                                           AIRPORT     CITY  \
# 0          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 1          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 2          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 3          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 4          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
#
#   STATE  YEAR  MONTH  DAY  FLIGHT_NUMBER SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 0    GA  2015      1    1           3268                0540           0556
# 1    GA  2015      1    1            902                0600           0619
# 2    GA  2015      1    1           1635                0625            NaN
# 3    GA  2015      1    1            886                0645           0644
# 4    GA  2015      1    1           4974                0646           0642
#
#    DEPARTURE_DELAY  CANCELLATION CANCELLATION_REASON
# ...

# %%
merged_table=merged_table[merged_table["DEPARTURE_DELAY"]>60.0]

# %%
date=[]
for index, row in merged_table.iterrows():
    year= row["YEAR"]
    month= row["MONTH"]
    day= row["DAY"]
    time= row["SCHEDULED_DEPARTURE"]
    date.append(pd.to_datetime(f"{year}-{month}-{day}-{time}").round('60min'))

# %%
merged_table['datetime'] = date
merged_table = merged_table.rename(columns={"CITY": "city",
                                            "DEPARTURE_DELAY": "departure_delay",
                                            "FLIGHT_NUMBER": "flight_number",
                                            "CANCELLATION": "cancellation"
                                                         })

merged_table.head()
# Out:
#     airport_code                                           AIRPORT     city  \
# 72           ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 159          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 177          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 234          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
# 292          ATL  Hartsfield-Jackson Atlanta International Airport  Atlanta
#
#     STATE  YEAR  MONTH  DAY  flight_number SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 72     GA  2015      1    1           1973                0925           1034
# 159    GA  2015      1    1           5082                1050           1205
# 177    GA  2015      1    1           1069                1105           1212
# 234    GA  2015      1    1           1655                1220           1321
# 292    GA  2015      1    1           1499                1350           1451
#
# ...

# %%
merged_table=merged_table.drop(['AIRPORT', 'STATE', 'YEAR', 'MONTH', 'DAY', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'CANCELLATION_REASON'], axis=1)
merged_table=merged_table[['datetime', 'airport_code', 'city', 'flight_number', 'departure_delay', 'cancellation']]

# %%
merged_table.head()
# Out:
#                datetime airport_code     city  flight_number  departure_delay  \
# 72  2015-01-01 09:00:00          ATL  Atlanta           1973             69.0
# 159 2015-01-01 11:00:00          ATL  Atlanta           5082             75.0
# 177 2015-01-01 11:00:00          ATL  Atlanta           1069             67.0
# 234 2015-01-01 12:00:00          ATL  Atlanta           1655             61.0
# 292 2015-01-01 14:00:00          ATL  Atlanta           1499             61.0
#
#      cancellation
# 72              0
# 159             0
# 177             0
# 234             0
# 292             0

# %%
weather_df2.head()
# Out:
#               datetime          atlanta          chicago   kansas_city  \
# 0  2012-10-01 12:00:00              NaN              NaN           NaN
# 1  2012-10-01 13:00:00       light rain  overcast clouds  sky is clear
# 2  2012-10-01 14:00:00  overcast clouds  overcast clouds  sky is clear
# 3  2012-10-01 15:00:00  overcast clouds  overcast clouds  sky is clear
# 4  2012-10-01 16:00:00  overcast clouds  overcast clouds  sky is clear
#
#      new_york san_francisco
# 0         NaN           NaN
# 1  few clouds    light rain
# 2  few clouds  sky is clear
# 3  few clouds  sky is clear
# 4  few clouds  sky is clear

# %%
weather_df2=weather_df2[weather_df2["datetime"]>="2015-01-01"]
weather_df2=weather_df2[weather_df2["datetime"]<="2015-12-31"]

# %%
weather_df2.head()
# Out:
#                   datetime       atlanta       chicago       kansas_city  \
# 19716  2015-01-01 00:00:00  sky is clear  sky is clear  scattered clouds
# 19717  2015-01-01 01:00:00  sky is clear  sky is clear  scattered clouds
# 19718  2015-01-01 02:00:00  sky is clear  sky is clear  scattered clouds
# 19719  2015-01-01 03:00:00  sky is clear  sky is clear  scattered clouds
# 19720  2015-01-01 04:00:00  sky is clear  sky is clear  scattered clouds
#
#            new_york san_francisco
# 19716  sky is clear  sky is clear
# 19717  sky is clear  sky is clear
# 19718  sky is clear  sky is clear
# 19719  sky is clear  sky is clear
# 19720  sky is clear  sky is clear

# %%
connection_string = "postgres:postgres@localhost:5432/ETL Project"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['flights', 'weather']

# %%
merged_table.to_sql(name='flights', con=engine, if_exists='append', index=True)
weather_df2.to_sql(name='weather', con=engine, if_exists='append', index=True)
